# %%
from moviepy.editor import *
clip =VideoFileClip("C:\\Users\\i340968\\Downloads\\2 - Introduction to SAP Basis.mp4")
clip1=clip.subclip(0,5)
clip1.ipython_display()
# Out:
# chunk:   2%|█▏                                                               | 2/111 [00:00<00:07, 15.01it/s, now=None]
# Moviepy - Building video __temp__.mp4.
# MoviePy - Writing audio in __temp__TEMP_MPY_wvf_snd.mp3
# t:   1%|▉                                                                    | 2/150 [00:00<00:09, 15.92it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
# displaying 4 this second as image


from moviepy.editor import *
clip =VideoFileClip("C:\\Users\\i340968\\Downloads\\2 - Introduction to SAP Basis.mp4")
clip1=clip.subclip(0,5)
clip1.ipython_display(t=4)
# Out:
# <div align=middle><img  src='data:image/png;base64,...'></div>

# %%
from moviepy.editor import *
clip =VideoFileClip("C:\\Users\\i340968\\Downloads\\2 - Introduction to SAP Basis.mp4")
clip1=clip.subclip(0,5)
clip1.ipython_display(t=72)
# Out:
# <div align=middle><img  src='data:image/png;base64,...'></div>

# %%
# writing video to local folder
from moviepy.editor import *
clip =VideoFileClip("C:\\Users\\i340968\\Downloads\\2 - Introduction to SAP Basis.mp4")
clip1=clip.subclip(0,5)
clip1.write_videofile("C:\\Users\\i340968\\Downloads\\edited.mp4")
clip1.ipython_display(t=72)
# Out:
# chunk:   2%|█▏                                                               | 2/111 [00:00<00:06, 16.99it/s, now=None]
# Moviepy - Building video C:\Users\i340968\Downloads\edited.mp4.
# MoviePy - Writing audio in editedTEMP_MPY_wvf_snd.mp3
# t:   1%|▉                                                                    | 2/150 [00:00<00:09, 16.04it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video C:\Users\i340968\Downloads\edited.mp4
# Moviepy - Done !
# Moviepy - video ready C:\Users\i340968\Downloads\edited.mp4
# <div align=middle><img  src='data:image/png;base64,...'></div>
